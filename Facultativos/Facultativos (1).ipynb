# %% [markdown]
# ##***AUTOR: Agustín Rojas***
#  agustinsilviorojas@outlook.com.ar
#
#
# **Redes Sociales:**
#
# ![image.png](data:image/png;base64,...)[LinkedIn](https://www.linkedin.com/in/agust%C3%ADnsilviorojas/)

# %% [markdown]
# El presente trabajo trata sobre poder resolver contratos facultativos como el siguiente: ![Parte c facultativo.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ####Instalamos los paquetes

# %%
# !pip install matplotlib
# !pip install numpy
# !pip uninstall -y pandas
# !pip install pandas --upgrade --force-reinstall
# Out:
# ...
# Found existing installation: pandas 2.2.2
# Uninstalling pandas-2.2.2:
#   Successfully uninstalled pandas-2.2.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 59.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 22.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ####Se puede importar como un array para no tener que importar el excel.

# %%
#Define the data as a NumPy array
#Definir los datos como un arreglo de NumPy
ruth_data = np.array([
    [0.0000, 100.00, 100.00, 100.00],
    [0.0001, 99.90, 99.99, 99.94],
    [0.0010, 96.10, 97.30, 96.70],
    [0.0011, 95.70, 97.10, 96.40],
    [0.0012, 95.40, 96.90, 96.15],
    [0.0013, 95.10, 96.70, 95.90],
    [0.0014, 94.80, 96.50, 95.65],
    [0.0015, 94.50, 96.30, 95.40],
    [0.0016, 94.20, 96.10, 95.15],
    [0.0017, 93.90, 95.90, 94.90],
    [0.0018, 93.60, 95.70, 94.65],
    [0.0019, 93.30, 95.50, 94.40],
    [0.0020, 93.00, 95.40, 94.20],
    [0.0021, 92.70, 95.30, 94.00],
    [0.0022, 92.50, 95.10, 93.80],
    [0.0023, 92.20, 95.00, 93.60],
    [0.0024, 91.90, 94.80, 93.35],
    [0.0025, 91.70, 94.70, 93.20],
    [0.0026, 91.50, 94.50, 93.00],
    [0.0027, 91.20, 94.40, 92.80],
    [0.0028, 90.90, 94.20, 92.55],
    [0.0029, 90.70, 94.10, 92.40],
    [0.0030, 90.40, 93.90, 92.15],
    [0.0031, 90.20, 93.80, 92.00],
    [0.0032, 89.90, 93.60, 91.75],
    [0.0033, 89.70, 93.50, 91.60],
    [0.0034, 89.50, 93.40, 91.45],
    [0.0035, 89.30, 93.30, 91.30],
    [0.0036, 89.00, 93.10, 91.05],
    [0.0037, 88.80, 93.00, 90.90],
    [0.0038, 88.60, 92.90, 90.75],
    [0.0039, 88.30, 92.70, 90.50],
    [0.0040, 88.10, 92.60, 90.35],
    [0.0041, 87.90, 92.50, 90.20],
    [0.0042, 87.70, 92.40, 90.05],
    [0.0043, 87.50, 92.20, 89.85],
    [0.0044, 87.30, 92.10, 89.70],
    [0.0045, 87.10, 92.00, 89.55],
    [0.0046, 86.90, 91.90, 89.40],
    [0.0047, 86.70, 91.80, 89.25],
    [0.0048, 86.50, 91.60, 89.05],
    [0.0049, 86.30, 91.50, 88.90],
    [0.0050, 86.10, 91.40, 88.75],
    [0.0051, 85.90, 91.30, 88.60],
    [0.0052, 85.70, 91.20, 88.45],
    [0.0053, 85.60, 91.10, 88.35],
    [0.0054, 85.40, 91.00, 88.20],
    [0.0055, 85.20, 90.90, 88.05],
    [0.0056, 85.00, 90.70, 87.85],
    [0.0057, 84.80, 90.60, 87.70],
    [0.0058, 84.70, 90.50, 87.60],
    [0.0059, 84.50, 90.40, 87.45],
    [0.0060, 84.30, 90.30, 87.30],
    [0.0061, 84.10, 90.20, 87.15],
    [0.0062, 83.90, 90.10, 87.00],
    [0.0063, 83.70, 90.00, 86.85],
    [0.0064, 83.50, 89.90, 86.70],
    [0.0065, 83.30, 89.80, 86.55],
    [0.0066, 83.10, 89.70, 86.40],
    [0.0067, 82.90, 89.60, 86.25],
    [0.6800, 5.10, 15.00, 10.05],
    [0.6810, 5.10, 14.90, 10.00],
    [0.6820, 5.00, 14.80, 9.90],
    [0.6830, 5.00, 14.70, 9.85],
    [0.6840, 5.00, 14.60, 9.80],
    [0.6850, 5.00, 14.60, 9.80],
    [0.6860, 4.90, 14.50, 9.70],
    [0.6870, 4.90, 14.50, 9.70],
    [0.6880, 4.90, 14.40, 9.65],
    [0.6890, 4.90, 14.40, 9.65],
    [0.6900, 4.90, 14.40, 9.65],
    [0.6910, 4.90, 14.30, 9.60],
    [0.6920, 4.80, 14.20, 9.50],
    [0.6930, 4.80, 14.10, 9.45],
    [0.6940, 4.70, 14.00, 9.35],
    [0.6950, 4.70, 14.00, 9.35],
    [0.6960, 4.70, 13.90, 9.30],
    [0.6970, 4.60, 13.90, 9.25],
    [0.6980, 4.60, 13.80, 9.20],
    [0.6990, 4.60, 13.80, 9.20],
    [0.7000, 4.60, 13.80, 9.20],
    [0.7010, 4.60, 13.70, 9.15],
    [0.7020, 4.50, 13.60, 9.05],
    [0.7030, 4.50, 13.60, 9.05],
    [0.7040, 4.50, 13.50, 9.00],
    [0.7050, 4.50, 13.50, 9.00],
    [0.7060, 4.40, 13.40, 8.90],
    [0.7070, 4.40, 13.40, 8.90],
    [0.7080, 4.40, 13.30, 6.65],
    [0.7090, 4.40, 13.30, 8.85],
    [0.7100, 4.40, 13.30, 8.85],
    [0.7110, 4.40, 13.20, 6.60],
    [0.7120, 4.30, 13.10, 8.70],
    [0.7130, 4.30, 13.10, 8.70],
    [0.7140, 4.30, 13.00, 8.65],
    [0.7150, 4.30, 13.00, 8.65],
    [0.7160, 4.20, 12.90, 8.55],
    [0.7170, 4.20, 12.90, 8.55],
    [0.7180, 4.20, 12.80, 8.50],
    [0.7190, 4.20, 12.80, 8.50],
    [0.7200, 4.20, 12.80, 8.50],
    [0.7210, 4.20, 12.70, 8.45],
    [0.7220, 4.10, 12.60, 6.35],
    [0.7230, 4.10, 12.50, 8.30],
    [0.7240, 4.10, 12.40, 8.25],
    [0.7250, 4.10, 12.40, 8.25],
    [0.7260, 4.10, 12.30, 8.20],
    [0.7270, 4.00, 12.30, 8.15],
    [0.7280, 4.00, 12.20, 8.10],
    [0.7290, 4.00, 12.20, 8.10],
    [0.7300, 4.00, 12.20, 8.10],
    [0.7310, 4.00, 12.10, 8.05],
    [0.7320, 3.90, 12.00, 7.95],
    [0.7330, 3.90, 12.00, 7.95],
    [0.7340, 3.90, 11.90, 7.90],
    [0.7350, 3.90, 11.90, 7.90],
    [0.7360, 3.80, 11.80, 7.80],
    [0.7370, 3.80, 11.80, 7.80],
    [0.7380, 3.80, 11.70, 7.75],
    [0.7390, 3.80, 11.70, 7.75],
    [0.7400, 3.80, 11.70, 7.75],
    [0.7410, 3.80, 11.60, 7.70],
    [0.7420, 3.70, 11.50, 7.60],
    [0.7430, 3.70, 11.50, 7.60],
    [0.7440, 3.70, 11.40, 7.55],
    [0.7450, 3.70, 11.40, 7.55],
    [0.7460, 3.60, 11.30, 7.45],
    [0.7470, 3.60, 11.30, 7.45],
    [0.7480, 3.60, 11.20, 7.40],
    [0.7490, 3.60, 11.20, 7.40],
    [0.7500, 3.60, 11.20, 7.40],
    [0.7510, 3.60, 11.10, 7.35],
    [0.7520, 3.50, 11.00, 7.25],
    [0.7530, 3.50, 11.00, 7.25],
    [0.7540, 3.50, 10.90, 7.20],
    [0.7550, 3.50, 10.90, 7.20],
    [0.7560, 3.40, 10.80, 7.10],
    [0.7570, 3.40, 10.80, 7.10],
    [0.7580, 3.40, 10.70, 7.05],
    [0.7590, 3.40, 10.70, 7.05],
    [0.7600, 3.40, 10.70, 7.05],
    [0.7610, 3.30, 10.60, 6.95],
    [0.7620, 3.30, 10.50, 6.90],
    [0.7630, 3.30, 10.40, 6.85],
    [0.7640, 3.30, 10.40, 6.85],
    [0.7650, 3.30, 10.30, 6.80],
    [0.7660, 3.20, 10.30, 6.75],
    [0.7670, 3.20, 10.20, 6.70],
    [0.7680, 3.20, 10.20, 6.70],
    [0.7690, 3.20, 10.20, 6.70],
    [0.7700, 3.20, 10.20, 6.70],
    [0.7710, 3.10, 10.10, 6.60],
    [0.7720, 3.10, 10.00, 6.55],
    [0.7730, 3.10, 9.90, 6.50],
    [0.7740, 3.10, 9.80, 6.45],
    [0.7750, 3.10, 9.80, 6.45],
    [0.7760, 3.00, 9.70, 6.35],
    [0.7770, 3.00, 9.70, 6.35],
    [0.7780, 3.00, 9.60, 6.30],
    [0.7790, 3.00, 9.60, 6.30],
    [0.7800, 3.00, 9.60, 6.30],
    [0.7810, 2.90, 9.50, 6.20],
    [0.7820, 2.90, 9.40, 6.15],
    [0.7830, 2.90, 9.40, 6.15],
    [0.7840, 2.90, 9.30, 6.10],
    [0.7850, 2.90, 9.30, 6.10],
    [0.7860, 2.80, 9.20, 6.00],
    [0.7870, 2.80, 9.20, 6.00],
    [0.7880, 2.80, 9.10, 5.95],
    [0.7890, 2.80, 9.10, 5.95],
    [0.7900, 2.80, 9.10, 5.95],
    [0.7910, 2.70, 9.00, 5.85],
    [0.7920, 2.70, 8.90, 5.80],
    [0.7930, 2.70, 8.80, 5.75],
    [0.7940, 2.70, 8.80, 5.75],
    [0.7950, 2.70, 8.70, 5.70],
    [0.7960, 2.60, 8.70, 5.65],
    [0.7970, 2.60, 8.60, 5.60],
    [0.7980, 2.60, 8.60, 5.60],
    [0.7990, 2.60, 8.60, 5.60],
    [0.8000, 2.60, 8.60, 5.60],
    [0.8010, 2.60, 8.50, 5.55],
    [0.8020, 2.60, 8.40, 5.50],
    [0.8030, 2.60, 8.30, 5.45],
    [0.8040, 2.60, 8.30, 5.45],
    [0.8050, 2.60, 8.20, 5.40],
    [0.8060, 2.50, 8.20, 5.35],
    [0.8070, 2.50, 8.10, 5.30],
    [0.8080, 2.50, 8.10, 5.30],
    [0.8090, 2.50, 8.10, 5.30],
    [0.8100, 2.50, 8.10, 5.30],
    [0.8110, 2.40, 8.00, 5.20],
    [0.8120, 2.40, 8.00, 5.20],
    [0.8130, 2.40, 7.90, 5.15],
    [0.8140, 2.40, 7.90, 5.15],
    [0.8150, 2.40, 7.80, 5.10],
    [0.8160, 2.30, 7.80, 5.05],
    [0.8170, 2.30, 7.70, 5.00],
    [0.8180, 2.30, 7.70, 5.00],
    [0.8190, 2.30, 7.70, 5.00],
    [0.8200, 2.30, 7.70, 5.00],
    [0.8210, 2.30, 7.60, 4.95],
    [0.8220, 2.30, 7.50, 4.90],
    [0.8230, 2.30, 7.40, 4.85],
    [0.8240, 2.30, 7.40, 4.85],
    [0.8250, 2.20, 7.30, 4.75],
    [0.8260, 2.20, 7.30, 4.75],
    [0.8270, 2.20, 7.20, 4.70],
    [0.8280, 2.20, 7.20, 4.70],
    [0.8290, 2.20, 7.20, 4.70],
    [0.8300, 2.20, 7.20, 4.70],
    [0.8310, 2.10, 7.10, 4.60],
    [0.8320, 2.10, 7.00, 4.55],
    [0.8330, 2.10, 7.00, 4.55],
    [0.8340, 2.10, 6.90, 4.50],
    [0.8350, 2.10, 6.90, 4.50],
    [0.8360, 2.00, 6.90, 4.45],
    [0.8370, 2.00, 6.80, 4.40],
    [0.8380, 2.00, 6.80, 4.40],
    [0.8390, 2.00, 6.80, 4.40],
    [0.8400, 2.00, 6.80, 4.40],
    [0.8410, 2.00, 6.70, 4.35],
    [0.8420, 2.00, 6.60, 4.30],
    [0.8430, 2.00, 6.60, 4.30],
    [0.8440, 2.00, 6.50, 4.25],
    [0.8450, 1.90, 6.50, 4.20],
    [0.8460, 1.90, 6.40, 4.15],
    [0.8470, 1.90, 6.40, 4.15],
    [0.8480, 1.90, 6.30, 4.10],
    [0.8490, 1.90, 6.30, 4.10],
    [0.8500, 1.90, 6.30, 4.10],
    [0.8510, 1.80, 6.20, 4.00],
    [0.8520, 1.80, 6.10, 3.95],
    [0.8530, 1.80, 6.10, 3.95],
    [0.8540, 1.80, 6.00, 3.90],
    [0.8550, 1.70, 6.00, 3.85],
    [0.8560, 1.70, 5.90, 3.80],
    [0.8570, 1.70, 5.90, 3.80],
    [0.8580, 1.70, 5.80, 3.75],
    [0.8590, 1.70, 5.80, 3.75],
    [0.8600, 1.70, 5.80, 3.75],
    [0.8610, 1.70, 5.70, 3.70],
    [0.8620, 1.70, 5.60, 3.65],
    [0.8630, 1.70, 5.60, 3.65],
    [0.8640, 1.70, 5.50, 3.60],
    [0.8650, 1.60, 5.50, 3.55],
    [0.8660, 1.60, 5.50, 3.55],
    [0.8670, 1.60, 5.40, 3.50],
    [0.8680, 1.60, 5.40, 3.50],
    [0.8690, 1.60, 5.40, 3.50],
    [0.8700, 1.60, 5.40, 3.50],
    [0.8710, 1.50, 5.30, 3.40],
    [0.8720, 1.50, 5.20, 3.35],
    [0.8730, 1.50, 5.10, 3.30],
    [0.8740, 1.50, 5.10, 3.30],
    [0.8750, 1.50, 5.00, 3.25],
    [0.8760, 1.40, 5.00, 3.20],
    [0.8770, 1.40, 4.90, 3.15],
    [0.8780, 1.40, 4.90, 3.15],
    [0.8790, 1.40, 4.90, 3.15],
    [0.8800, 1.40, 4.90, 3.15],
    [0.8810, 1.40, 4.80, 3.10],
    [0.8820, 1.40, 4.80, 3.10],
    [0.8830, 1.40, 4.70, 3.05],
    [0.8840, 1.40, 4.70, 3.05],
    [0.8850, 1.30, 4.60, 2.95],
    [0.8860, 1.30, 4.60, 2.95],
    [0.8870, 1.30, 4.50, 2.90],
    [0.8880, 1.30, 4.50, 2.90],
    [0.8890, 1.30, 4.50, 2.90],
    [0.8900, 1.30, 4.50, 2.90],
    [0.8910, 1.20, 4.40, 2.80],
    [0.8920, 1.20, 4.30, 2.75],
    [0.8930, 1.20, 4.20, 2.70],
    [0.8940, 1.20, 4.20, 2.72],
    [0.8950, 1.20, 4.10, 2.65],
    [0.8960, 1.10, 4.10, 2.60],
    [0.8970, 1.10, 4.00, 2.55],
    [0.8980, 1.10, 4.00, 2.55],
    [0.8990, 1.10, 4.00, 2.55],
    [0.9000, 1.10, 4.00, 2.55],
    [0.9010, 1.10, 3.90, 2.50],
    [0.9020, 1.10, 3.80, 2.45],
    [0.9030, 1.10, 3.80, 2.45],
    [0.9040, 1.10, 3.70, 2.40],
    [0.9050, 1.00, 3.70, 2.35],
    [0.9060, 1.00, 3.70, 2.35],
    [0.9070, 1.00, 3.60, 2.30],
    [0.9080, 1.00, 3.60, 2.30],
    [0.9090, 1.00, 3.60, 2.30],
    [0.9100, 1.00, 3.60, 2.30],
    [0.9110, 1.00, 3.50, 2.25],
    [0.9120, 1.00, 3.40, 2.20],
    [0.9130, 1.00, 3.40, 2.20],
    [0.9140, 1.00, 3.30, 2.15],
    [0.9150, 0.90, 3.30, 2.10],
    [0.9160, 0.90, 3.30, 2.10],
    [0.9170, 0.90, 3.20, 2.05],
    [0.9180, 0.90, 3.20, 2.05],
    [0.9190, 0.90, 3.20, 2.05],
    [0.9200, 0.90, 3.20, 2.05],
    [0.9210, 0.90, 3.10, 2.00],
    [0.9220, 0.90, 3.00, 1.95],
    [0.9230, 0.90, 3.00, 1.95],
    [0.9240, 0.90, 2.90, 1.90],
    [0.9250, 0.90, 2.90, 1.90],
    [0.9260, 0.80, 2.90, 1.85],
    [0.9270, 0.80, 2.80, 1.80],
    [0.9280, 0.80, 2.80, 1.80],
    [0.9290, 0.80, 2.80, 1.80],
    [0.9300, 0.80, 2.80, 1.80],
    [0.9310, 0.80, 2.70, 1.75],
    [0.9320, 0.80, 2.60, 1.70],
    [0.9330, 0.80, 2.60, 1.70],
    [0.9340, 0.80, 2.50, 1.65],
    [0.9350, 0.80, 2.50, 1.65],
    [0.9360, 0.70, 2.50, 1.60],
    [0.9370, 0.70, 2.40, 1.55],
    [0.9380, 0.70, 2.40, 1.55],
    [0.9390, 0.70, 2.40, 1.55],
    [0.9400, 0.70, 2.40, 1.55],
    [0.9410, 0.70, 2.30, 1.50],
    [0.9420, 0.70, 2.20, 1.45],
    [0.9430, 0.70, 2.20, 1.45],
    [0.9440, 0.70, 2.10, 1.40],
    [0.9450, 0.70, 2.10, 1.40],
    [0.9460, 0.60, 2.10, 1.35],
    [0.9470, 0.60, 2.00, 1.30],
    [0.9480, 0.60, 2.00, 1.30],
    [0.9490, 0.60, 2.00, 1.30],
    [0.9500, 0.60, 2.00, 1.30],
    [0.9510, 0.50, 1.90, 1.20],
    [0.9520, 0.50, 1.80, 1.15],
    [0.9530, 0.50, 1.80, 1.15],
    [0.9540, 0.50, 1.70, 1.10],
    [0.9550, 0.50, 1.70, 1.10],
    [0.9560, 0.40, 1.70, 1.05],
    [0.9570, 0.40, 1.60, 1.00],
    [0.9580, 0.40, 1.60, 1.00],
    [0.9590, 0.40, 1.60, 1.00],
    [0.9600, 0.40, 1.60, 1.00],
    [0.9610, 0.40, 1.50, 0.95],
    [0.9620, 0.40, 1.40, 0.90],
    [0.9630, 0.40, 1.40, 0.90],
    [0.9640, 0.40, 1.30, 0.85],
    [0.9650, 0.40, 1.30, 0.85],
    [0.9660, 0.30, 1.30, 0.80],
    [0.9670, 0.30, 1.20, 0.75],
    [0.9680, 0.30, 1.20, 0.75],
    [0.9690, 0.30, 1.20, 0.75],
    [0.9700, 0.30, 1.20, 0.75],
    [0.9710, 0.30, 1.10, 0.70],
    [0.9720, 0.30, 1.00, 0.65],
    [0.9730, 0.30, 1.00, 0.65],
    [0.9740, 0.30, 0.90, 0.60],
    [0.9750, 0.30, 0.90, 0.60],
    [0.9760, 0.20, 0.90, 0.55],
    [0.9770, 0.20, 0.80, 0.50],
    [0.9780, 0.20, 0.80, 0.50],
    [0.9790, 0.20, 0.80, 0.50],
    [0.9800, 0.20, 0.80, 0.50],
    [0.9810, 0.20, 0.70, 0.45],
    [0.9820, 0.20, 0.60, 0.40],
    [0.9830, 0.20, 0.50, 0.35],
    [0.9840, 0.20, 0.50, 0.35],
    [0.9850, 0.20, 0.50, 0.35],
    [0.9860, 0.10, 0.50, 0.30],
    [0.9870, 0.10, 0.40, 0.25],
    [0.9880, 0.10, 0.40, 0.25],
    [0.9890, 0.10, 0.40, 0.25],
    [0.9900, 0.10, 0.40, 0.25],
    [0.9910, 0.10, 0.30, 0.20],
    [0.9920, 0.10, 0.30, 0.20],
    [0.9930, 0.10, 0.20, 0.15],
    [0.9940, 0.10, 0.20, 0.15],
    [0.9950, 0.10, 0.20, 0.15],
    [0.9960, 0.10, 0.10, 0.10],
    [0.9970, 0.10, 0.10, 0.10],
    [0.9980, 0.10, 0.10, 0.10],
    [0.9990, 0.10, 0.10, 0.10],
    [1.0000, 0.00, 0.00, 0.00]
    ])

#Define column names
#Definir los nombres de las columnas
columns = ['X/S', 'A', 'B', 'AB']

#Create the DataFrame
#Crear el DataFrame
df_ruth_table_numpy = pd.DataFrame(ruth_data, columns=columns)

#Display the first few rows
#Mostrar las primeras filas
print(df_ruth_table_numpy.head())
# Out:
#       X/S      A       B      AB
# 0  0.0000  100.0  100.00  100.00
# 1  0.0001   99.9   99.99   99.94
# 2  0.0010   96.1   97.30   96.70
# 3  0.0011   95.7   97.10   96.40
# 4  0.0012   95.4   96.90   96.15

# %% [markdown]
# #### Importar el excel de tablas de ruth

# %%
# Ask the user to upload the Excel file
from google.colab import files
uploaded = files.upload()  # This will prompt the user to select a file

# Read the uploaded Excel file into a DataFrame
# Replace "Ruth Tables.xlsx" with the uploaded file's name
import io
import openpyxl  # Ensure openpyxl is installed

# Get the uploaded file name
filename = next(iter(uploaded))

# Read the Excel file
df_ruth = pd.read_excel(io.BytesIO(uploaded[filename]), engine="openpyxl")

# Display the first few rows of the DataFrame
print(df_ruth.head())
# Out:
#      <input type="file" id="files-5ab0b770-dc84-4dd0-b45d-d0e842dca85b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ab0b770-dc84-4dd0-b45d-d0e842dca85b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #Ruth E. Salzmann

# %% [markdown]
# Las tablas de Salzmann se utilizaron principalmente para la tarificación de contratos de reaseguro de exceso de pérdida por riesgo de patrimonial no proporcional. Este método, conocido como "calificación por exposición", es crucial en situaciones donde el reasegurador no dispone de un historial de siniestros creíble suficiente de la parte asegurada.
#
# Limitaciones y críticas:
#
# A pesar de su amplia relevancia, las tablas de Salzmann presentaban limitaciones importantes:
#
# **Antigüedad de los Datos:**
#
#   Las curvas originales se basaron en datos de siniestros por incendio de viviendas de 1960. Esto significa que los valores numéricos específicos de las tablas estaban desactualizados debido a los cambios en las prácticas de construcción, códigos de edificación, tecnologías de protección contra incendios, valores de las propiedades y el panorama general de riesgos a lo largo del tiempo.
#
# **Intención Original de Salzmann:**
#
#  La propia Salzmann concibió sus curvas "solo como un ejemplo" para demostrar su metodología y explícitamente "no las recomendó para uso posterior" como herramientas de tarificación universales. Esto indica que su uso prolongado sin actualizaciones o ajustes podría haber llevado a inexactitudes.
#
# **Diferencia entre Datos y Aplicación:**
#
#  Los datos de siniestros utilizados en su análisis original "difieren significativamente de lo que típicamente cubre un contrato de reaseguro de exceso de pérdida de propiedad".
#
#
# **Dependencia de Datos Externos:**
#
#   El método de calificación por exposición requiere que el reasegurador asigne un alto grado de credibilidad a fuentes de datos que no son propias, dependiendo de datos derivados de otras aseguradoras y sistemas de calificación de terceros.
#
# **Aproximaciones:**
#    Una desventaja del método es que pueden haber porcentajes de retención donde las pérdidas se aproximan.

# %% [markdown]
# Salzmann tables were primarily used for rating non-proportional property excess of loss reinsurance contracts. This method, known as "exposure rating", is crucial in situations where the reinsurer does not have a sufficient credible loss history from the insured party.
#
# Limitations and critics:
# Despite their wide relevance, the Salzmann tables had significant limitations:
#
# **Data Age:**
#
#  The original curves were based on residential fire loss data from 1960. This means that the specific numerical values in the tables were outdated due to changes in construction practices, building codes, fire protection technologies, property values, and the overall risk landscape over time.
#
# **Salzmann's Original Intent:**
#
# Salzmann herself conceived her curves "only as an example" to demonstrate her methodology and explicitly "did not recommend them for further use" as universal rating tools. This indicates that their prolonged use without updates or adjustments could have led to inaccuracies.
#
# **Difference Between Data and Application:**
#
# The loss data used in her original analysis "differs significantly from what is typically covered by a property excess of loss reinsurance treaty."
#
# **Dependence on External Data:**
#
#  The exposure rating method requires the reinsurer to assign a high degree of credibility to data sources that are not their own, relying on data derived from other insurers and third-party rating systems.
#
# **Loss Zone:**
#
# A disadvantage of the method is that it creates a zone in each layer where losses approach, but do not reach, the next level of retention.

# %% [markdown]
# #Riesgos

# %%
riesgo1 = np.array([
    ["Edificio", 12000000, 0.0003],
    ["Contenido", 12000000, 0.0008]
    ["Maquinaria", 5000000, 0.0005]])

riesgo2 = np.array([
    ["Edificio", 2500000, 0.00055],
    ["Contenido", 3000000, 0.0011]
    ["Maquinaria", 2400000, 0.0006]])

#Define column names
#Definir los nombres de las columnas
columnas_riesgos = ['Cobertura', 'SA', 'Tasa_prima']

#Create the DataFrame
#Crear el DataFrame
df_riesgo1 = pd.DataFrame(riesgo1, columns=columnas_riesgos)

#Display the first few rows
#Mostrar las primeras filas
print(df_riesgo1.head())

# %% [markdown]
# #Programa reaseguro

# %%
Programa_de_Reaseguros = np.array(["NP", "xs",

# %% [markdown]
# Función para agregar guardar los datos de los contratos de reaseguro.

# %%
# Listas válidas para validación
CLASES_VALIDAS = ["Proporcional", "No proporcional"]
TIPOS_VALIDOS = [
   "QS", "SPL", "XL por riesgo", "XL por acontecimiento",
   "XL por Catástrofe", "Stop Loss", "Stop Loss por ejercicio"
]

# Crear DataFrame vacío si no existe
try:
   contratos_reaseguro
except NameError:
   contratos_reaseguro = pd.DataFrame(columns=[
    "id_contrato", "nombre_contrato", "clase_contrato", "tipo_contrato",
    "fecha_inicio", "fecha_fin", "retencion", "limite", "capacidad",
    "afecta_facultativo", "activo", "reaseguradora", "comentarios"
   ])

def cargar_contrato(
   df=contratos_reaseguro,
   id_contrato=None,
   nombre_contrato=None,
   clase_contrato=None,
   tipo_contrato=None,
   fecha_inicio=None,
   fecha_fin=None,
   retencion=0.0,
   limite=0.0,
   afecta_facultativo=False,
   reaseguradora=None,
   comentarios=""
):
   """
   Carga un contrato de reaseguro en el DataFrame con validaciones.

   Parámetros:
    df: DataFrame destino (por defecto contratos_reaseguro)
    id_contrato: ID único del contrato
    nombre_contrato: Nombre o alias del contrato
    clase_contrato: "Proporcional" o "No proporcional"
    tipo_contrato: Tipo específico (ej. "QS", "XL por riesgo", etc.)
    fecha_inicio: Fecha de inicio en formato "dd/mm/yyyy"
    fecha_fin: Fecha de fin en formato "dd/mm/yyyy"
    retencion: Monto de retención (no negativo)
    limite: Monto de límite (no negativo)
    afecta_facultativo: Booleano si afecta al facultativo
    reaseguradora: Nombre de la reaseguradora
    comentarios: Texto adicional

   Retorna:
    DataFrame actualizado con el nuevo contrato
   """

   # Validar clase de contrato
   if clase_contrato not in CLASES_VALIDAS:
    raise ValueError(f"Clase de contrato inválida. Debe ser una de: {CLASES_VALIDAS}")

   # Validar tipo de contrato
   if tipo_contrato not in TIPOS_VALIDOS:
    raise ValueError(f"Tipo de contrato inválido. Debe ser uno de: {TIPOS_VALIDOS}")

   # Validar fechas y convertir a datetime
   try:
    fecha_inicio_dt = datetime.strptime(fecha_inicio, "%d/%m/%Y")
    fecha_fin_dt = datetime.strptime(fecha_fin, "%d/%m/%Y")
   except ValueError:
    raise ValueError("Formato de fecha inválido. Use 'dd/mm/yyyy'.")

   if fecha_inicio_dt >= fecha_fin_dt:
    raise ValueError("La fecha de inicio debe ser anterior a la fecha de fin.")

   # Validar retención y límite
   if retencion < 0 or limite < 0:
    raise ValueError("Retención y límite deben ser valores no negativos.")

   # Calcular capacidad
   capacidad = retencion + limite

   # Determinar si el contrato está activo (vigente hoy)
   hoy = datetime.today()
   activo = fecha_inicio_dt <= hoy <= fecha_fin_dt

   # Crear nuevo registro
   nuevo_contrato = {
    "id_contrato": id_contrato,
    "nombre_contrato": nombre_contrato,
    "clase_contrato": clase_contrato,
    "tipo_contrato": tipo_contrato,
    "fecha_inicio": fecha_inicio_dt,
    "fecha_fin": fecha_fin_dt,
    "retencion": retencion,
    "limite": limite,
    "capacidad": capacidad,
    "afecta_facultativo": afecta_facultativo,
    "activo": activo,
    "reaseguradora": reaseguradora,
    "comentarios": comentarios
   }

   # Agregar al DataFrame
   df = pd.concat([df, pd.DataFrame([nuevo_contrato])], ignore_index=True)

   return df

# %%
# DataFrames vacíos (puedes cargarlos de archivos si ya existen)
try:
    contratos_reaseguro
except NameError:
    contratos_reaseguro = pd.DataFrame(columns=[
        "id_contrato", "nombre_contrato", "clase_contrato", "tipo_contrato",
        "fecha_inicio", "fecha_fin", "retencion", "limite", "capacidad",
        "prioridad", "afecta_facultativo", "activo", "id_reaseguradora",
        "id_moneda", "pais", "ramo", "producto", "cobertura", "comentarios"
    ])
try:
    reaseguradoras
except NameError:
    reaseguradoras = pd.DataFrame(columns=["id_reaseguradora", "nombre_reaseguradora", "pais", "rating", "comentarios"])
try:
    monedas
except NameError:
    monedas = pd.DataFrame(columns=["id_moneda", "nombre_moneda", "codigo_iso"])
try:
    clausulas
except NameError:
    clausulas = pd.DataFrame(columns=["id_clausula", "id_contrato", "tipo_clausula", "descripcion", "valor", "unidad", "comentarios"])

CLASES_VALIDAS = ["Proporcional", "No proporcional"]
TIPOS_PROPORCIONALES = ["QS", "SPL"]
TIPOS_NO_PROPORCIONALES = [
    "XL por riesgo", "XL por acontecimiento", "XL por Catástrofe",
    "Stop Loss", "Stop Loss por ejercicio"
]

def cargar_contrato_interactivo(df=contratos_reaseguro):
    """
    Carga un contrato de reaseguro pidiendo los datos al usuario.
    El id_contrato se asigna automáticamente.
    """
    print("=== Alta de contrato de reaseguro ===")
    nombre_contrato = input("Nombre del contrato: ")

    # Clase de contrato
    print("Clase de contrato:")
    for i, clase in enumerate(CLASES_VALIDAS):
        print(f"{i+1}. {clase}")
    clase_idx = int(input("Seleccione clase (número): ")) - 1
    clase_contrato = CLASES_VALIDAS[clase_idx]

    # Tipo de contrato
    tipos = TIPOS_PROPORCIONALES if clase_contrato == "Proporcional" else TIPOS_NO_PROPORCIONALES
    print("Tipo de contrato:")
    for i, tipo in enumerate(tipos):
        print(f"{i+1}. {tipo}")
    tipo_idx = int(input("Seleccione tipo (número): ")) - 1
    tipo_contrato = tipos[tipo_idx]

    # Fechas
    fecha_inicio = input("Fecha de inicio (dd/mm/yyyy): ")
    fecha_fin = input("Fecha de fin (dd/mm/yyyy): ")
    fecha_inicio_dt = datetime.strptime(fecha_inicio, "%d/%m/%Y")
    fecha_fin_dt = datetime.strptime(fecha_fin, "%d/%m/%Y")

    # Retención, límite, prioridad
    retencion = float(input("Retención (número): "))
    limite = float(input("Límite (número): "))
    prioridad = float(input("Prioridad (número, 0 si no aplica): "))
    capacidad = retencion + limite

    # Afecta facultativo
    afecta_facultativo = input("¿Afecta al facultativo? (s/n): ").lower() == "s"

    # Reaseguradora (elige o crea)
    if reaseguradoras.empty:
        print("No hay reaseguradoras cargadas. Ingrese nombre de la reaseguradora:")
        nombre_rea = input("Nombre reaseguradora: ")
        id_rea = 0
        reaseguradoras.loc[id_rea] = [id_rea, nombre_rea, "", "", ""]
    else:
        print("Reaseguradoras disponibles:")
        for i, row in reaseguradoras.iterrows():
            print(f"{row['id_reaseguradora']}: {row['nombre_reaseguradora']}")
        id_rea = int(input("Seleccione id de reaseguradora (o -1 para nueva): "))
        if id_rea == -1:
            nombre_rea = input("Nombre reaseguradora: ")
            id_rea = reaseguradoras['id_reaseguradora'].max() + 1 if not reaseguradoras.empty else 0
            reaseguradoras.loc[id_rea] = [id_rea, nombre_rea, "", "", ""]

    # Moneda (elige o crea)
    if monedas.empty:
        print("No hay monedas cargadas. Ingrese nombre y código ISO:")
        nombre_moneda = input("Nombre moneda: ")
        codigo_iso = input("Código ISO: ")
        id_moneda = 0
        monedas.loc[id_moneda] = [id_moneda, nombre_moneda, codigo_iso]
    else:
        print("Monedas disponibles:")
        for i, row in monedas.iterrows():
            print(f"{row['id_moneda']}: {row['nombre_moneda']} ({row['codigo_iso']})")
        id_moneda = int(input("Seleccione id de moneda (o -1 para nueva): "))
        if id_moneda == -1:
            nombre_moneda = input("Nombre moneda: ")
            codigo_iso = input("Código ISO: ")
            id_moneda = monedas['id_moneda'].max() + 1 if not monedas.empty else 0
            monedas.loc[id_moneda] = [id_moneda, nombre_moneda, codigo_iso]

    # Otros campos
    pais = input("País (libre): ")
    ramo = input("Ramo (libre): ")
    producto = input("Producto (libre): ")
    cobertura = input("Cobertura (libre): ")
    comentarios = input("Comentarios adicionales (opcional): ")

    # Estado activo
    hoy = datetime.today()
    activo = fecha_inicio_dt <= hoy <= fecha_fin_dt

    # id automático
    id_contrato = df['id_contrato'].max() + 1 if not df.empty else 0

    # Crear registro
    nuevo_contrato = {
        "id_contrato": id_contrato,
        "nombre_contrato": nombre_contrato,
        "clase_contrato": clase_contrato,
        "tipo_contrato": tipo_contrato,
        "fecha_inicio": fecha_inicio_dt,
        "fecha_fin": fecha_fin_dt,
        "retencion": retencion,
        "limite": limite,
        "capacidad": capacidad,
        "prioridad": prioridad,
        "afecta_facultativo": afecta_facultativo,
        "activo": activo,
        "id_reaseguradora": id_rea,
        "id_moneda": id_moneda,
        "pais": pais,
        "ramo": ramo,
        "producto": producto,
        "cobertura": cobertura,
        "comentarios": comentarios
    }

    df = pd.concat([df, pd.DataFrame([nuevo_contrato])], ignore_index=True)
    print("Contrato cargado correctamente.")
    return df

# Puedes crear funciones similares para cargar reaseguradoras, monedas y cláusulas.

# %%
cargar_contrato(
   clase_contrato= "Proporcional",
   tipo_contrato="QS",
   fecha_inicio="14/1/2025",
   fecha_fin= "14/1/2026",
   retencion=1000000,
   limite=1000000,
)

# %%
cargar_contrato_interactivo()

# %% [markdown]
# #Graficos

# %% [markdown]
# Pasos a seguir: 1ro calcular la cantidad de capas para el grafico, 2do calcular la participacion dentro de cada capa.
#
# Paso3:
#
# Liquidar siniestros: Ver cuál es el monto de siniestros y distribuirlos según el gráfico. por capas. Para aquellas capas que tienen más de una aseguradora, distribuir el monto correspondientee a esa capa  según el porcentaje de participación de esa capa.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from openpyxl import load_workbook
from openpyxl.drawing.image import Image as XLImage

# Datos de participación por capa y aseguradora. Editarlo para que sea la cantidad respectiva del programa.
data = {
    'Capa': ['1st Layer', '2nd Layer', '3rd Layer', '4th Layer'],
    'Desde': [0, 1_000_000, 3_000_000, 6_000_000],
    'Hasta': [1_000_000, 3_000_000, 6_000_000, 10_000_000],
    'Aseguradora A': [0, 2_000_000, 3_000_000, 2_000_000],
    'Aseguradora B': [0, 0, 0, 2_000_000],
    'Deducible': [1_000_000, 0, 0, 0]
}

df = pd.DataFrame(data)

List_participantes_programa = [col for col in df.columns if col not in ['Capa', 'Desde', 'Hasta']]




# Altura total de la suma asegurada
total_sa = 10_000_000

# %%
# Crear gráfico
fig, ax = plt.subplots(figsize=(6, 8))

# Para evitar etiquetas duplicadas en la leyenda
legend_labels = {}

# Colores por aseguradora
colors = {
    'Aseguradora A': '#1f77b4',
    'Aseguradora B': '#ff7f0e',
    'Deducible': '#2ca02c'
}

# Dibujar cada capa como una caja de igual altura
for i, row in df.iterrows():
    capa_altura = row['Hasta'] - row['Desde']
    bottom = row['Desde']
    total_participacion = sum(row[aseg] for aseg in List_participantes_programa)
    if total_participacion == 0:
        continue
    left = 0

    for aseguradora in List_participantes_programa:
        participacion = row[aseguradora]
        if participacion > 0:
            ancho = participacion / total_participacion
            bar = ax.barh(
                y=(bottom + capa_altura / 2),
                width=ancho,
                height=capa_altura,
                left=left,
                color=colors[aseguradora],
                edgecolor='black'
            )
            # Añadir etiqueta con el nombre de la aseguradora
            ax.text(
                x=left + ancho / 2,
                y=(bottom + capa_altura / 2),
                s=aseguradora,
                va='center',
                ha='center',
                fontsize=8,
                color='white',
                weight='bold'
            )
            if aseguradora not in legend_labels:
                legend_labels[aseguradora] = bar[0]
            left += ancho


# Configurar eje y
ax.set_ylim(0, total_sa)
ax.set_xlim(0, 1)
ax.set_xlabel('Participación proporcional')
ax.set_ylabel('Suma Asegurada')
ax.set_title('Distribución de Capas y Participación por Aseguradora')
ax.set_yticks([0, 1_000_000, 3_000_000, 6_000_000, 10_000_000])
ax.set_yticklabels(['0', '1M', '3M', '6M', '10M'])

# Agregar leyenda con etiquetas únicas
ax.legend(legend_labels.values(), legend_labels.keys(), loc='upper right')

# Guardar gráfico como imagen
plt.tight_layout()
plt.savefig("grafico_facultativo.png")


# Guardar datos y explicación en Excel
with pd.ExcelWriter("esquema_facultativo.xlsx", engine='openpyxl') as writer:
    df.to_excel(writer, sheet_name='Datos', index=False)

    instrucciones = [
        "INSTRUCCIONES PARA EDITAR Y ENTENDER EL GRÁFICO",
        "",
        "1. Cada fila en la hoja 'Datos' representa una capa del contrato.",
        "2. Las columnas 'Desde' y 'Hasta' indican el intervalo de suma asegurada cubierto por esa capa.",
        "3. Las columnas de aseguradoras indican cuánto cubre cada una dentro de esa capa.",
        "4. El gráfico muestra una barra vertical de 0 a 10 millones.",
        "5. Cada capa tiene la misma altura visual, y si hay más de una aseguradora, se divide horizontalmente.",
        "6. Para modificar el gráfico, edite los valores en la hoja 'Datos' y regenere el gráfico con el script."
    ]
    instrucciones_df = pd.DataFrame({'Instrucciones': instrucciones})
    instrucciones_df.to_excel(writer, sheet_name='Instrucciones', index=False)

# Cargar el archivo Excel y agregar el gráfico como imagen en una nueva hoja
wb = load_workbook("esquema_facultativo.xlsx")
ws = wb.create_sheet("Gráfico")
img = XLImage("grafico_facultativo.png")
ws.add_image(img, "A1")
wb.save("esquema_facultativo.xlsx")

# %% [markdown]
# #Liquidación de Siniestros

# %%
import pandas as pd

# Datos de participación por capa y aseguradora. Editarlo para que sea la cantidad respectiva del programa.
data = {
    'Capa': ['1st Layer', '2nd Layer', '3rd Layer', '4th Layer'],
    'Desde': [0, 1_000_000, 3_000_000, 6_000_000],
    'Hasta': [1_000_000, 3_000_000, 6_000_000, 10_000_000],
    'Aseguradora A': [0, 2_000_000, 3_000_000, 2_000_000],
    'Aseguradora B': [0, 0, 0, 2_000_000],
    'Deducible': [1_000_000, 0, 0, 0]
}

df = pd.DataFrame(data)

# Detectar columnas numéricas y aplicar formato
formato = {col: '{:,.0f}' for col in df.select_dtypes(include='number').columns}
df.style.format(formato)



List_participantes_programa = [col for col in df.columns if col not in ['Capa', 'Desde', 'Hasta']]

# Siniestro total
siniestro_total = 9_500_000

# Inicializar resultados
resultados = []

# Recorrer cada capa
for i, row in df.iterrows():
    capa_desde = row['Desde']
    capa_hasta = row['Hasta']
    monto_capa = min(siniestro_total, capa_hasta) - capa_desde
    if monto_capa <= 0:
        continue

    total_participacion = sum(row[aseg] for aseg in List_participantes_programa)

    if total_participacion == 0:
        continue

    capa_resultado = {'Capa': row['Capa'], 'Monto Capa': monto_capa}
    for aseguradora in List_participantes_programa:
        participacion = row[aseguradora]
        monto_pagado = monto_capa * (participacion / total_participacion)
        capa_resultado[aseguradora] = monto_pagado
    resultados.append(capa_resultado)

# Convertir resultados a DataFrame
df_resultado = pd.DataFrame(resultados)

# Mostrar resultados
for participante in List_participantes_programa:
    print(f"{participante} se hará cargo de ${df_resultado[participante].sum():,.0f}")

df_resultado

# %% [markdown]
# #Bibliografía

# %% [markdown]
#  Investopedia. (n.d.). Exposure Rating: Meaning, Method, Limitations. https://www.investopedia.com/terms/e/exposure-rating.asp
#  Vse.cz. (2019). Exposure curves play significant role in modelling of property perrisk excess of loss non-proportional reinsurance contracts, especially in the situations when not enough historical data is available for applying experience-based methods or if the underlying exposure changed significantly. https://pep.vse.cz/pdfs/pep/2019/02/01.pdf
#  Casualty Actuarial Society. (1990). Included in the 1963 Proceedings is the paper “Rating by Layer of Insurance”, by Ruth Salsmann.  https://www.casact.org/sites/default/files/database/dpp_dpp90_90dpp395.pdf
#  Boston Funeral Home. (n.d.). Obituaries: Ruth E. Salzmann.  https://www.bostonfuneralhome.net/obituaries/Ruth-E-Salzmann?obId=569247
#  Casualty Actuarial Society. (2014). Ruth E. Salzmann (FCAS 1947) 1919-2014. https://www.casact.org/sites/default/files/2021-02/pubs_proceed_obituaries_salzmann_ruth-2014.pdf
#  ResearchGate. (2019). Exposure Modelling in Property Reinsurance.  https://www.researchgate.net/publication/330836785_Exposure_Modelling_in_Property_Reinsurance
